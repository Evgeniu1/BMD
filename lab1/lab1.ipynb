# %% [markdown]
#  <h1>BMD</h1>
#  <h1>BC-82</h1>
#  <h1>Бондарчук Євгеній</h1>

# %% [markdown]
# 1. Введення даних вручну

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 9.8 MB 1.9 MB/s eta 0:00:0136     |██████████▏                     | 3.1 MB 1.6 MB/s eta 0:00:05
# ...
#      |████████████████████████████████| 509 kB 1.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
new_df = pd.DataFrame(
    {
 
    "Country": ["Ukraine", "Poland", "Germany", "Austria"],
    "Capital": ["Kyiv", "Warszawa", "Berlin", "Vienna"],
    "Area":    [603549, 312679, 357385, 83879],
    "Population": [41880000, 38313035, 83019200, 8923507],
    "Currency": ["Hryvnia", "Zloty", "Euro", "Euro"],
    "Language": ["Ukrainian", "Polish", "German", "German"]
    
})
new_df
# Out:
#    Country   Capital    Area  Population Currency   Language
# 0  Ukraine      Kyiv  603549    41880000  Hryvnia  Ukrainian
# 1   Poland  Warszawa  312679    38313035    Zloty     Polish
# 2  Germany    Berlin  357385    83019200     Euro     German
# 3  Austria    Vienna   83879     8923507     Euro     German

# %% [markdown]
# 2.Завантаження даних з CSV файлу

# %% [markdown]
# 2.1 Завантаження даних з вказанням повного шляху

# %%
path = "/Users/evgeniu/Desktop/jupyter/data.csv"
data = pd.read_csv(path, encoding='utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2.2 Завантаження файлу що розміщений в робочій директорії

# %%
import os

print("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: /Users/evgeniu/Desktop/jupyter

# %%
data = pd.read_csv('data.csv')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 3. Відображення даних

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# 4. Базова статистика про дані

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# 5. Використання функції 'describe'

# %%
data['Make'].describe()
# Out:
# count         11914
# unique           48
# top       Chevrolet
# freq           1123
# Name: Make, dtype: object

# %%
data['Engine HP'].describe()
# Out:
# count    11845.00000
# mean       249.38607
# std        109.19187
# min         55.00000
# 25%        170.00000
# 50%        227.00000
# 75%        300.00000
# max       1001.00000
# Name: Engine HP, dtype: float64

# %%
cut_data = data.iloc[0:10, :]

cut_data
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
new_data = ["fast", "fast", "fast", "slow", "slow", "slow", "fast", "fast", "slow", "slow"]
cut_data.insert(1, "Feeling of control", new_data)
cut_data
# Out:
#   Make Feeling of control       Model  Year             Engine Fuel Type  \
# 0  BMW               fast  1 Series M  2011  premium unleaded (required)
# 1  BMW               fast    1 Series  2011  premium unleaded (required)
# 2  BMW               fast    1 Series  2011  premium unleaded (required)
# 3  BMW               slow    1 Series  2011  premium unleaded (required)
# 4  BMW               slow    1 Series  2011  premium unleaded (required)
# 5  BMW               slow    1 Series  2012  premium unleaded (required)
# 6  BMW               fast    1 Series  2012  premium unleaded (required)
# 7  BMW               fast    1 Series  2012  premium unleaded (required)
# 8  BMW               slow    1 Series  2012  premium unleaded (required)
# 9  BMW               slow    1 Series  2013  premium unleaded (required)
#
#    Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 0      335.0               6.0            MANUAL  rear wheel drive
# ...

# %% [markdown]
# 6. Виведення статистики з розділенням на групи

# %%
cut_data.groupby('Feeling of control').describe()
# Out:
#                     Year                                                    \
#                    count    mean       std     min     25%     50%     75%
# Feeling of control
# fast                 5.0  2011.4  0.547723  2011.0  2011.0  2011.0  2012.0
# slow                 5.0  2011.8  0.836660  2011.0  2011.0  2012.0  2012.0
#
#                            Engine HP         ... Popularity          MSRP  \
#                        max     count   mean  ...        75%     max count
# Feeling of control                           ...
# fast                2012.0       5.0  307.0  ...     3916.0  3916.0   5.0
# slow                2013.0       5.0  230.0  ...     3916.0  3916.0   5.0
#
#                                                                               \
#                        mean          std      min      25%      50%      75%
# Feeling of control
# fast                41307.0  3877.563023  36350.0  39300.0  40650.0  44100.0
# ...

# %% [markdown]
# 7. Збереження даних

# %%
cut_data.to_csv("cut_data.csv", encoding='utf8')
